# %%
import pandas as pd

# %%
# I want a pkl file like the one of epicKitchen but for action_net

ek_dataframe = pd.read_pickle('train_val/D1_train.pkl')

ek_dataframe.head()
# Out:
#      uid participant_id video_id     narration start_timestamp stop_timestamp  \
# 0  12915            P08   P08_01   open fridge     00:00:04.09    00:00:05.84
# 1  12916            P08   P08_01      get milk     00:00:05.94    00:00:07.23
# 2  12917            P08   P08_01  close fridge     00:00:07.29    00:00:08.95
# 3  12918            P08   P08_01      get moka     00:00:10.64    00:00:13.50
# 4  12919            P08   P08_01   place water     00:00:15.72    00:00:21.14
#
#    start_frame  stop_frame   verb  verb_class
# 0          245         350   open           2
# 1          356         433    get           0
# 2          437         537  close           3
# 3          638         810    get           0
# 4          943        1268  place           1

# %%
type(ek_dataframe.iloc[0].start_timestamp)
# Out:
# str

# %%
# I have this information spread on two types of file

an_annotations_train = pd.read_pickle('action-net/ActionNet_train.pkl')
an_annotations_test = pd.read_pickle('action-net/ActionNet_test.pkl')

len(pd.unique(an_annotations_test['labels']))
pd.unique(an_annotations_train['labels'])
# Out:
# array(['Spread', 'Get/Put', 'Clear', 'Slice', 'Clean', 'Pour', 'Load',
#        'Peel', 'Open/Close', 'Set', 'Stack', 'Unload'], dtype=object)

# %%
len(an_annotations_train.loc[an_annotations_train['file'] == "S04_1.pkl"])
# Out:
# 51

# %%
len(an_annotations_test.loc[an_annotations_test['file'] == "S04_1.pkl"])
# Out:
# 8

# %%
S04_1 = pd.read_pickle('../an_data/EMG/S04_1.pkl')

S04_1['duration'] = S04_1.apply(lambda row: row.stop - row.start, axis=1)

# %%
print(f"Avg duration(Actionnet): {S04_1['duration'].sum()/len(S04_1)} s")
# Out:
# Avg duration(Actionnet): 46.82497415542603 s

# %%
# number of frames:

S04_1['duration'].sum()*30
# Out:
# 84284.95347976685

# %%
from datetime import datetime

ts = S04_1.iloc[0].start

type(ts)

datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S.%f')
# Out:
# '2022-06-14 22:38:34.183343'

# %%
START_TS = datetime.fromtimestamp(S04_1.iloc[0].start)
S04_1['start_timestamp_raw'] = S04_1.apply(lambda row: datetime.fromtimestamp(row.start), axis=1)
S04_1['stop_timestamp_raw'] = S04_1.apply(lambda row: datetime.fromtimestamp(row.stop), axis=1)

S04_1['start_timestamp'] = S04_1.apply(lambda row: str(row.start_timestamp_raw - START_TS).replace('0 days', '').lstrip(), axis=1)
S04_1['stop_timestamp'] = S04_1.apply(lambda row: str(row.stop_timestamp_raw - START_TS).replace('0 days', '').lstrip(), axis=1)


S04_1['start_frame'] = S04_1.apply(lambda row: int((row.start_timestamp_raw - START_TS).total_seconds()*30 + 1), axis=1)
S04_1['stop_frame'] = S04_1.apply(lambda row: int((row.stop_timestamp_raw - START_TS).total_seconds()*30+1), axis=1)

# %%
S04_1.head()
# Out:
#                                          description         start  \
# 0                                        calibration  1.655239e+09
# 1  Get/replace items from refrigerator/cabinets/d...  1.655240e+09
# 2                                    Peel a cucumber  1.655240e+09
# 3                                    Peel a cucumber  1.655240e+09
# 4                                    Peel a cucumber  1.655240e+09
#
#            stop                                myo_left_timestamps  \
# 0  1.655240e+09                                                 []
# 1  1.655240e+09  [1655239974.420555, 1655239974.432055, 1655239...
# 2  1.655240e+09  [1655240064.7444172, 1655240064.748419, 165524...
# 3  1.655240e+09  [1655240130.5200577, 1655240130.531557, 165524...
# 4  1.655240e+09  [1655240178.033217, 1655240178.037216, 1655240...
#
#                                    myo_left_readings  \
# 0                                                 []
# 1  [[8, 7, 2, 2, 6, 5, 14, 2], [-4, 23, 19, 6, 16...
# 2  [[78, 57, 43, 7, 18, 18, 4, 16], [3, 0, 48, 6,...
# 3  [[-30, 20, 18, 1, 12, 23, 21, -10], [23, -15, ...
# 4  [[4, -19, -26, -63, -31, -36, -3, -1], [-30, -...
#
#                                 myo_right_timestamps  \
# 0                                                 []
# 1  [1655239974.4195595, 1655239974.427058, 165523...
# 2  [1655240064.7504191, 1655240064.76542, 1655240...
# 3  [1655240130.5190585, 1655240130.526558, 165524...
# 4  [1655240178.0472164, 1655240178.062216, 165524...
#
#                                   myo_right_readings    duration  \
# 0                                                 []  860.235713
# 1  [[-2, -3, 2, 3, -8, -1, 1, -2], [3, 7, 8, -1, ...   76.253382
# 2  [[-18, 14, 26, -3, -15, -12, -26, 4], [-20, -2...   48.258168
# 3  [[1, -21, 22, 14, 13, -24, -1, -12], [-58, -83...   36.551677
# 4  [[-4, 57, 49, 32, 34, 7, 7, 7], [-13, -80, -29...   46.207925
#
#          start_timestamp_raw         stop_timestamp_raw  start_timestamp  \
# 0 2022-06-14 22:38:34.183343 2022-06-14 22:52:54.419056         00:00:00
# 1 2022-06-14 22:52:54.419056 2022-06-14 22:54:10.672438  00:14:20.235713
# 2 2022-06-14 22:54:24.742419 2022-06-14 22:55:13.000587  00:15:50.559076
# 3 2022-06-14 22:55:30.515558 2022-06-14 22:56:07.067235  00:16:56.332215
# 4 2022-06-14 22:56:18.033217 2022-06-14 22:57:04.241142  00:17:43.849874
#
#     stop_timestamp  start_frame  stop_frame
# 0  00:14:20.235713            1       25808
# 1  00:15:36.489095        25808       28095
# 2  00:16:38.817244        28517       29965
# 3  00:17:32.883892        30490       31587
# 4  00:18:30.057799        31916       33302

# %%
VERBS = {verb: i for i, verb in enumerate(an_annotations_train.labels.unique().tolist())}
VERBS
# Out:
# {'Spread': 0,
#  'Get/Put': 1,
#  'Clear': 2,
#  'Slice': 3,
#  'Clean': 4,
#  'Pour': 5,
#  'Load': 6,
#  'Peel': 7,
#  'Open/Close': 8,
#  'Set': 9,
#  'Stack': 10,
#  'Unload': 11}

# %%
result = []
actual_uid = 0
for i in range(len(an_annotations_train)):
    row = an_annotations_train.iloc[i]
    if row.file == "S04_1.pkl":
        idx = row[0]
        sample = S04_1.iloc[idx]
        result.append({
            'uid': actual_uid,
            'start_ts': sample.start_timestamp,
            'end_ts': sample.stop_timestamp,
            'verb': row.labels,
            'verb_class': VERBS[row.labels],
            'description': sample.description,
            'start_frame': sample.start_frame,
            'stop_frame': sample.stop_frame,
            'subject': row.file.split('_')[0]
        })
        actual_uid += 1
        
result = pd.DataFrame(result)
result_test = []

for i in range(len(an_annotations_test)):
    row = an_annotations_test.iloc[i]
    if row.file == "S04_1.pkl":
        idx = row[0]
        sample = S04_1.iloc[idx]
        result_test.append({
            'uid': actual_uid,
            'start_ts': sample.start_timestamp,
            'end_ts': sample.stop_timestamp,
            'verb': row.labels,
            'verb_class': VERBS[row.labels],
            'description': sample.description,
            'start_frame': sample.start_frame,
# 0   Get/replace items from refrigerator/cabinets/d...        42403
# 1                                    Slice a cucumber        35308
# 2                                      Slice a potato        53626
# 3                         Clean a plate with a sponge        78721
# 4              Pour water from a pitcher into a glass        72709
# 5               Spread almond butter on a bread slice        64879
# 6                           Clean a pan with a sponge        80209
# 7                   Open/close a jar of almond butter        69105
# 8                       Spread jelly on a bread slice        66503
# 9   Get/replace items from refrigerator/cabinets/d...        61313
# 10                                Clear cutting board        54514
# 11                           Clean a pan with a towel        80794
# 12                      Spread jelly on a bread slice        66019
# 13                           Clean a pan with a towel        81243
# 14  Get/replace items from refrigerator/cabinets/d...        25808
# 15                                Clear cutting board        40751
# 16                                    Peel a cucumber        30490
# 17                                        Slice bread        57672
# 18   Stack on table: 3 each large/small plates, bowls        90873
# 19                  Open/close a jar of almond butter        68633
# 20             Pour water from a pitcher into a glass        72966
# 21             Pour water from a pitcher into a glass        73460
# 22                        Clean a plate with a sponge        78272
# 23  Load dishwasher: 3 each large/small plates, bo...        92537
# 24                          Clean a pan with a sponge        80395
# 25                                   Slice a cucumber        37296
# 26              Spread almond butter on a bread slice        63744
# 27  Get items from cabinets: 3 each large/small pl...        83429
# 28                                Clear cutting board        67825
# 29                                Clear cutting board        50904
# 30                        Clean a plate with a sponge        78422
# 31  Get/replace items from refrigerator/cabinets/d...        75451
# 32  Unload dishwasher: 3 each large/small plates, ...        96204
# 33                                      Peel a potato        48705
# 34                                Clear cutting board        33734
# 35                         Clean a plate with a towel        79264
# 36             Pour water from a pitcher into a glass        73161
# 37                                      Peel a potato        44947
# 38                                        Slice bread        58445
# 39  Get/replace items from refrigerator/cabinets/d...        70068
# 40                                     Slice a potato        51765
# 41                                        Slice bread        59066
# 42                                    Peel a cucumber        28517
# 43                                      Peel a potato        47339
# 44                                    Peel a cucumber        31916
# 45                                   Slice a cucumber        39036
# 46                                     Slice a potato        52724
# 47                      Spread jelly on a bread slice        67004
# 48  Get/replace items from refrigerator/cabinets/d...        55489
# 49                          Clean a pan with a sponge        79953
# 50  Get/replace items from refrigerator/cabinets/d...        81703
#
#     stop_frame subject
# 0        44509     S04
# 1        36764     S04
# 2        54357     S04
# 3        78861     S04
# 4        72856     S04
# 5        65328     S04
# 6        80333     S04
# 7        69359     S04
# 8        66944     S04
# 9        63287     S04
# 10       55108     S04
# 11       80930     S04
# 12       66429     S04
# 13       81435     S04
# 14       28095     S04
# 15       42101     S04
# 16       31587     S04
# 17       58022     S04
# 18       92249     S04
# 19       68991     S04
# 20       73078     S04
# 21       73708     S04
# 22       78366     S04
# 23       95796     S04
# 24       80548     S04
# 25       38675     S04
# 26       64196     S04
# 27       86778     S04
# 28       68340     S04
# 29       51529     S04
# 30       78654     S04
# 31       77893     S04
# 32      101572     S04
# 33       50503     S04
# 34       34991     S04
# 35       79492     S04
# 36       73344     S04
# 37       47088     S04
# 38       58889     S04
# 39       72269     S04
# 40       52649     S04
# 41       59696     S04
# 42       29965     S04
# 43       48566     S04
# 44       33302     S04
# 45       40192     S04
# 46       53570     S04
# 47       67464     S04
# 48       57245     S04
# 49       80139     S04
# 50       82653     S04

# %%
import pickle

with open("train_val/S04_train.pkl", 'wb') as out:
    pickle.dump(result, out)

with open("train_val/S04_test.pkl", 'wb') as out:
    pickle.dump(result_test, out)
